# %% [markdown]
# ## Inverse Dynamics of a Planar Two-Link RP Robot Arm

# %%
from sympy import *
from sympy.physics.mechanics import LagrangesMethod, dynamicsymbols
import numpy as np
from IPython.display import display, Markdown, Math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def dispmath(lhs, rhs): display(Math(f'{lhs} = {latex(rhs)}'))

# %% [markdown]
# ![Two-Link RP Robot Arm](two-link_RP_robot_arm.png)

# %% [markdown]
# Defining the necessary symbols/functions:

# %%
m1, m2, l1, l2, g, t = symbols('m1, m2, l1, l2, g, t')
th1, th2 = dynamicsymbols('theta1, theta2')

# %% [markdown]
# Defining the positions of the centers of mass based on the angle and the extension:

# %%
x1 = l1*cos(th1); dispmath('x_1', x1)
y1 = l1*sin(th1); dispmath('y_1', y1)
x2 = x1 + l2*cos(th2); dispmath('x_2', x2)
y2 = y1 + l2*sin(th2); dispmath('y_2', y2)
# Out:
# $\displaystyle x_1 = l_{1} \cos{\left(\theta_{1}{\left(t \right)} \right)}$
# $\displaystyle y_1 = l_{1} \sin{\left(\theta_{1}{\left(t \right)} \right)}$
# $\displaystyle x_2 = l_{1} \cos{\left(\theta_{1}{\left(t \right)} \right)} + l_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)}$
# $\displaystyle y_2 = l_{1} \sin{\left(\theta_{1}{\left(t \right)} \right)} + l_{2} \sin{\left(\theta_{2}{\left(t \right)} \right)}$

# %% [markdown]
# Differentiating the positions with respect to time:

# %%
x1d = x1.diff(t); dispmath('\\dot{x_1}', x1d)
y1d = y1.diff(t); dispmath('\\dot{y_1}', y1d)
x2d = x2.diff(t); dispmath('\\dot{x_2}', x2d)
y2d = y2.diff(t); dispmath('\\dot{y_2}', y2d)
v1 = (x1d**2 + y1d**2)**(1/2); dispmath('\\dot{v_1}', v1)
v2 = (x2d**2 + y2d**2)**(1/2); dispmath('\\dot{v_2}', v2)
# Out:
# $\displaystyle \dot{x_1} = - l_{1} \sin{\left(\theta_{1}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)}$
# $\displaystyle \dot{y_1} = l_{1} \cos{\left(\theta_{1}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)}$
# $\displaystyle \dot{x_2} = - l_{1} \sin{\left(\theta_{1}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)} - l_{2} \sin{\left(\theta_{2}{\left(t \right)} \right)} \frac{d}{d t} \theta_{2}{\left(t \right)}$
# $\displaystyle \dot{y_2} = l_{1} \cos{\left(\theta_{1}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)} + l_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)} \frac{d}{d t} \theta_{2}{\left(t \right)}$
# $\displaystyle \dot{v_1} = \left(l_{1}^{2} \sin^{2}{\left(\theta_{1}{\left(t \right)} \right)} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2} + l_{1}^{2} \cos^{2}{\left(\theta_{1}{\left(t \right)} \right)} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2}\right)^{0.5}$
# $\displaystyle \dot{v_2} = \left(\left(- l_{1} \sin{\left(\theta_{1}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)} - l_{2} \sin{\left(\theta_{2}{\left(t \right)} \right)} \frac{d}{d t} \theta_{2}{\left(t \right)}\right)^{2} + \left(l_{1} \cos{\left(\theta_{1}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)} + l_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)} \frac{d}{d t} \theta_{2}{\left(t \right)}\right)^{2}\right)^{0.5}$

# %% [markdown]
# Introducing shorthands for derivatives:

# %%
thd1 = Derivative(th1, t)
thdd1 = Derivative(thd1, t)
thd2 = Derivative(th2, t)
thdd2 = Derivative(thd2, t)

# %% [markdown]
# Computing the kinetic and potential energies:

# %%
Ek1 = simplify((m1*(x1d**2 + y1d**2)/2) + (m1*l1**2/12)*thd1**2/2)
Ek2 = simplify((m2*(x2d**2 + y2d**2)/2) + (m2*l2**2/12)*thd2**2/2)

Ep1 = m1*g*y1
Ep2 = m2*g*y2

dispmath('E_{k1}', Ek1)
dispmath('E_{k2}', Ek2)
dispmath('E_{p1}', Ep1)
dispmath('E_{p2}', Ep2)
# Out:
# $\displaystyle E_{k1} = \frac{13 l_{1}^{2} m_{1} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2}}{24}$
# $\displaystyle E_{k2} = \frac{m_{2} \cdot \left(12 l_{1}^{2} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2} + 12 l_{1} l_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2} + 12 l_{1} l_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)} \frac{d}{d t} \theta_{2}{\left(t \right)} + 3 l_{2}^{2} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2} + 6 l_{2}^{2} \frac{d}{d t} \theta_{1}{\left(t \right)} \frac{d}{d t} \theta_{2}{\left(t \right)} + 4 l_{2}^{2} \left(\frac{d}{d t} \theta_{2}{\left(t \right)}\right)^{2}\right)}{24}$
# $\displaystyle E_{p1} = g l_{1} m_{1} \sin{\left(\theta_{1}{\left(t \right)} \right)}$
# $\displaystyle E_{p2} = g m_{2} \left(l_{1} \sin{\left(\theta_{1}{\left(t \right)} \right)} + \frac{l_{2} \sin{\left(\theta_{1}{\left(t \right)} + \theta_{2}{\left(t \right)} \right)}}{2}\right)$

# %% [markdown]
# The Lagrangian function:

# %%
L = simplify(Ek1 + Ek2 - Ep1 - Ep2)
dispmath('L', L)
# Out:
# $\displaystyle L = - g l_{1} m_{1} \sin{\left(\theta_{1}{\left(t \right)} \right)} - \frac{g m_{2} \cdot \left(2 l_{1} \sin{\left(\theta_{1}{\left(t \right)} \right)} + l_{2} \sin{\left(\theta_{1}{\left(t \right)} + \theta_{2}{\left(t \right)} \right)}\right)}{2} + \frac{13 l_{1}^{2} m_{1} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2}}{24} + \frac{m_{2} \cdot \left(12 l_{1}^{2} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2} + 12 l_{1} l_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2} + 12 l_{1} l_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)} \frac{d}{d t} \theta_{2}{\left(t \right)} + 3 l_{2}^{2} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2} + 6 l_{2}^{2} \frac{d}{d t} \theta_{1}{\left(t \right)} \frac{d}{d t} \theta_{2}{\left(t \right)} + 4 l_{2}^{2} \left(\frac{d}{d t} \theta_{2}{\left(t \right)}\right)^{2}\right)}{24}$

# %% [markdown]
# Forming Lagrange's equations of motion:

# %%
LM = LagrangesMethod(L, (th1, th2))
eqns = LM.form_lagranges_equations()
dispmath('\\begin{bmatrix} T \\\\ F \\end{bmatrix}', eqns)
# Out:
# $\displaystyle \begin{bmatrix} T \\ F \end{bmatrix} = \left[\begin{matrix}g l_{1} m_{1} \cos{\left(\theta_{1}{\left(t \right)} \right)} + \frac{g m_{2} \cdot \left(2 l_{1} \cos{\left(\theta_{1}{\left(t \right)} \right)} + l_{2} \cos{\left(\theta_{1}{\left(t \right)} + \theta_{2}{\left(t \right)} \right)}\right)}{2} + \frac{13 l_{1}^{2} m_{1} \frac{d^{2}}{d t^{2}} \theta_{1}{\left(t \right)}}{12} + \frac{m_{2} \cdot \left(24 l_{1}^{2} \frac{d^{2}}{d t^{2}} \theta_{1}{\left(t \right)} - 24 l_{1} l_{2} \sin{\left(\theta_{2}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)} \frac{d}{d t} \theta_{2}{\left(t \right)} - 12 l_{1} l_{2} \sin{\left(\theta_{2}{\left(t \right)} \right)} \left(\frac{d}{d t} \theta_{2}{\left(t \right)}\right)^{2} + 24 l_{1} l_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)} \frac{d^{2}}{d t^{2}} \theta_{1}{\left(t \right)} + 12 l_{1} l_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)} \frac{d^{2}}{d t^{2}} \theta_{2}{\left(t \right)} + 6 l_{2}^{2} \frac{d^{2}}{d t^{2}} \theta_{1}{\left(t \right)} + 6 l_{2}^{2} \frac{d^{2}}{d t^{2}} \theta_{2}{\left(t \right)}\right)}{24}\\\frac{g l_{2} m_{2} \cos{\left(\theta_{1}{\left(t \right)} + \theta_{2}{\left(t \right)} \right)}}{2} - \frac{m_{2} \left(- 12 l_{1} l_{2} \sin{\left(\theta_{2}{\left(t \right)} \right)} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2} - 12 l_{1} l_{2} \sin{\left(\theta_{2}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)} \frac{d}{d t} \theta_{2}{\left(t \right)}\right)}{24} + \frac{m_{2} \left(- 12 l_{1} l_{2} \sin{\left(\theta_{2}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)} \frac{d}{d t} \theta_{2}{\left(t \right)} + 12 l_{1} l_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)} \frac{d^{2}}{d t^{2}} \theta_{1}{\left(t \right)} + 6 l_{2}^{2} \frac{d^{2}}{d t^{2}} \theta_{1}{\left(t \right)} + 8 l_{2}^{2} \frac{d^{2}}{d t^{2}} \theta_{2}{\left(t \right)}\right)}{24}\end{matrix}\right]$

# %% [markdown]
# Turning the equations of motion into functions that take numerical values:

# %%
params = [m1, m2, l1, l2, g, th1, thd1, thdd1, th2, thd2, thdd2]
T_lambda = utilities.lambdify(params, eqns[0])
F_lambda = utilities.lambdify(params, eqns[1])

# %% [markdown]
# Introducing numerical values:

# %%
M1 = 1.4
M2 = 1.1
L1 = 0.9
L2 = 0.8
G = 9.81

# %% [markdown]
# Plotting the general shape of the trajectory:

# %%
dx = 0.01
xs = np.arange(0, 10 + dx, dx)
ys = np.sin(3*xs) * np.cos(2*xs) * 2 * np.sin(3*xs)
plt.plot(xs, ys)
plt.grid()

# %% [markdown]
# Fitting the assumed trajectory into a rectangle within the work area:

# %%
th_n = np.pi / 6
x_min = L1 * np.cos(th_n)
y_min = L1 * np.sin(th_n)
x_max = x_min + L2 * np.cos(th_n)
y_max = y_min + L2 * np.sin(th_n)

# %%
def fit(x, x_min, x_max):
    fitted = (x - np.min(x)) * (x_max - x_min) / (np.max(x) - np.min(x)) + x_min
    return fitted

# %%
x_traj = fit(xs, x_min, x_max)
y_traj = fit(ys, y_min, y_max)
plt.plot(x_traj, y_traj)
plt.grid()
plt.xlim([-0.1, 2])
plt.ylim([-0.1, 2])
# Out:
# (-0.1, 2.0)

# %% [markdown]
# Conversion from the trajectory points to the joint variables:

# %%
TH = np.arctan(y_traj / x_traj)
LA = np.sqrt(x_traj**2 + y_traj**2) - L2/2

# %%
def interpolate(array, num_elements):
    old_indices = np.arange(len(array))
    new_indices = np.linspace(0, len(array) - 1, num_elements)
    array_interpolated = np.interp(new_indices, old_indices, array)
    return array_interpolated

# %% [markdown]
# Numerical differentiation:

# %%
ts = np.linspace(0, 10, len(TH))
dt = ts[1] - ts[0]

THd = np.diff(TH) / dt
THd = interpolate(THd, len(TH))
THdd = np.diff(THd) / dt
THdd = interpolate(THdd, len(TH))

LAd = np.diff(LA) / dt
LAd = interpolate(LAd, len(LA))
LAdd = np.diff(LAd) / dt
LAdd = interpolate(LAdd, len(LA))

# %% [markdown]
# Calculating the required torque and force:

# %%
T_req = T_lambda(M1, M2, L1, L2, G, TH, THd, THdd, LA, LAd, LAdd)
F_req = F_lambda(M1, M2, L1, L2, G, TH, THd, THdd, LA, LAd, LAdd)

# %% [markdown]
# Plotting the torque:

# %%
plt.plot(ts, T_req)
plt.grid()
plt.xlabel('t [$s$]')
plt.ylabel('T [$N \cdot m$]')
# Out:
# Text(0, 0.5, 'T [$N \\cdot m$]')

# %% [markdown]
# Plotting the force:

# %%
plt.plot(ts, F_req)
plt.grid()
plt.xlabel('t [$s$]')
plt.ylabel('F [$N$]')
# Out:
# Text(0, 0.5, 'F [$N$]')
